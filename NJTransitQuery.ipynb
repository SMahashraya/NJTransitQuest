# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Read csv files into pandas dataframes
stations = "NJ_Railroad_Stations.csv"
delays = "NJT_Performance_2018_09.csv"

stations_df = pd.read_csv(stations)
delays_df = pd.read_csv(delays)

# Preview the data to find a common key
stations_df.tail()
stations_df["STATION"].unique()
delays_df.tail()
delays_df["from"].unique()
# Out:
# array(['Gladstone', 'Peapack', 'Far Hills', 'Bernardsville',
#        'Basking Ridge', 'Lyons', 'Millington', 'Stirling', 'Gillette',
#        'Berkeley Heights', 'Murray Hill', 'New Providence', 'Hoboken',
#        'Newark Broad Street', 'Watsessing Avenue', 'Bloomfield',
#        'Glen Ridge', 'Summit', 'Waldwick', 'Ho-Ho-Kus', 'Ridgewood',
#        'Glen Rock Boro Hall', 'Radburn Fair Lawn', 'Broadway Fair Lawn',
#        'Plauderville', 'Garfield', 'Wesmont', 'Rutherford',
#        'Secaucus Lower Lvl', 'Bay Head', 'Point Pleasant Beach',
#        'Manasquan', 'Spring Lake', 'Belmar', 'Bradley Beach',
#        'Asbury Park', 'Allenhurst', 'Elberon', 'Long Branch',
#        'Philadelphia', 'Trenton', 'Newark Penn Station', 'Metropark',
#        'New York Penn Station', 'Bay Street', 'Kingsland', 'Lyndhurst',
#        'Delawanna', 'Passaic', 'Clifton', 'Paterson', 'Hawthorne',
#        'Glen Rock Main Line', 'Union', 'Roselle Park', 'Cranford',
#        'Westfield', 'Fanwood', 'Netherwood', 'Plainfield', 'Dunellen',
#        'Bound Brook', 'Bridgewater', 'Somerville', 'Princeton Junction',
#        'Allendale', 'Ramsey Main St', 'Ramsey Route 17', 'Mahwah',
#        'Secaucus Upper Lvl', 'Newark Airport', 'Elizabeth', 'Linden',
#        'Rahway', 'Metuchen', 'Edison', 'New Brunswick', 'Hamilton',
#        'Suffern', 'Princeton', 'North Elizabeth', 'Woodbridge',
#        'Perth Amboy', 'South Amboy', 'Aberdeen-Matawan', 'Hazlet',
#        'Middletown NJ', 'Red Bank', 'Little Silver', 'Monmouth Park',
#        'Raritan', 'East Orange', 'Brick Church', 'Orange',
#        'Highland Avenue', 'South Orange', 'Maplewood', 'Millburn',
#        'Short Hills', 'Chatham', 'Madison', 'Convent Station',
#        'Morristown', 'Morris Plains', 'Mount Tabor', 'Denville',
#        'Spring Valley', 'Nanuet', 'Pearl River', 'Montvale', 'Park Ridge',
#        'Hillsdale', 'Westwood', 'Emerson', 'Oradell', 'River Edge',
#        'New Bridge Landing', 'Anderson Street', 'Essex Street',
#        'Wood Ridge', 'Pennsauken', 'Cherry Hill', 'Lindenwold', 'Atco',
#        'Hammonton', 'Egg Harbor City', 'Absecon', 'Dover',
#        'Mountain Station', 'Atlantic City Rail Terminal', 'Garwood',
#        'Sloatsburg', 'Tuxedo', 'Harriman', 'Salisbury Mills-Cornwall',
#        'Campbell Hall', 'Middletown NY', 'Otisville', 'Port Jervis',
#        'Jersey Avenue', 'Teterboro', 'Woodcliff Lake', 'High Bridge',
#        'Annandale', 'Lebanon', 'White House', 'North Branch', 'Avenel',
#        'Mount Olive', 'Netcong', 'Lake Hopatcong', 'Mount Arlington',
#        'Walnut Street', 'Watchung Avenue', 'Upper Montclair',
#        'Mountain Avenue', 'Montclair Heights', 'Montclair State U',
#        'Little Falls', 'Wayne-Route 23', 'Mountain View', 'Lincoln Park',
#        'Towaco', 'Boonton', 'Mountain Lakes', 'Hackettstown',
#        'Secaucus Concourse'], dtype=object)

# %%
# Merge dataframes based on a common key
NJT_df = pd.merge(stations_df, delays_df, left_on = "STATION", right_on = "from")

# Preview merged dataframe
NJT_df.head()
NJT_df[["AMTRAK", "type"]].loc[NJT_df["type"] == "Amtrak"]

# Clean your data and par down to most relevant columns for analysis
NJT_df["RAIL_LINE"] = NJT_df["RAIL_LINE"].replace(["Gladstone Branch/M&E", 
                                    "Main/Bergen Line", 
                                    "Montclair-Boonton Line/M&E", 
                                    "Morristown Line/M&E", 
                                    "River LINE"], ["Gladstone Branch", 
                                                    "Main Line", 
                                                    "Montclair-Boonton Line", 
                                                    "Morristown Line", "River Line"])
NJT_df["line"] = NJT_df["line"].replace(["AMTRAK", 
                                         "Atl. City Line", 
                                         "CAROLINIAN", 
                                         "PALMETTO",
                                         "Pascack Valley",
                                         "PENNSYLVANIAN", 
                                         "REGIONAL", 
                                         "SILVER METEOR-R", 
                                         "VERMONTER -R", 
                                         "ACELA EXPRESS", 
                                         "SILVER STAR -R", 
                                         "CRESCENT", 
                                         "Regional", 
                                         "Raritan Valley", 
                                         "Bergen Co. Line", 
                                         "Northeast Corrdr", 
                                         "No Jersey Coast", 
                                         "AMTRAK REGIONAL", 
                                         "KEYSTONE", 
                                         "Montclair-Boonton"], ["Amtrak",
                                                                "Atlantic City Line",
                                                                "Carolinian",
                                                                "Palmetto",
                                                                "Pascack Valley Line",
                                                                "Pennsylvanian",
                                                                "Regional Line",
                                                                "Silver Meteor - R",
                                                                "Vermonter - R", 
                                                                "Acela Express", 
                                                                "Silver Star - R", 
                                                                "Crescent", 
                                                                "Regional Line", 
                                                                "Raritan Valley Line", 
                                                                "Bergen County Line", 
                                                                "Northeast Corridor", 
                                                                "North Jersey Coast Line", 
                                                                "Amtrack Regional", 
                                                                "Keystone", 
                                                                "Montclair-Boonton Line"])

NJT_df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'COUNTY', 'LATITUDE', 'LONGITUDE', 'STATION',
#        'RAIL_LINE', 'MUN_LABEL', 'ATIS_ID', 'AMTRAK', 'date', 'train_id',
#        'stop_sequence', 'from', 'from_id', 'to', 'to_id', 'scheduled_time',
#        'actual_time', 'delay_minutes', 'status', 'line', 'type'],
#       dtype='object')

# %%
NJT_df.head()
# Out:
#              X            Y  OBJECTID    COUNTY   LATITUDE  LONGITUDE  \
# 0  621972.9957  480099.1444         2  MONMOUTH  40.150567  -74.03546
# 1  621972.9957  480099.1444         2  MONMOUTH  40.150567  -74.03546
# 2  621972.9957  480099.1444         2  MONMOUTH  40.150567  -74.03546
# 3  621972.9957  480099.1444         2  MONMOUTH  40.150567  -74.03546
# 4  621972.9957  480099.1444         2  MONMOUTH  40.150567  -74.03546
#
#        STATION                RAIL_LINE            MUN_LABEL   ATIS_ID  \
# 0  Spring Lake  North Jersey Coast Line  Spring Lake Borough  RAIL0141
# 1  Spring Lake  North Jersey Coast Line  Spring Lake Borough  RAIL0141
# 2  Spring Lake  North Jersey Coast Line  Spring Lake Borough  RAIL0141
# 3  Spring Lake  North Jersey Coast Line  Spring Lake Borough  RAIL0141
# 4  Spring Lake  North Jersey Coast Line  Spring Lake Borough  RAIL0141
#
#       ...             from from_id         to  to_id scheduled_time  \
# 0     ...      Spring Lake   141.0     Belmar   15.0   9/1/18 10:38
# 1     ...      Spring Lake   141.0  Manasquan   79.0    9/1/18 9:12
# 2     ...      Spring Lake   141.0     Belmar   15.0   9/1/18 21:36
# 3     ...      Spring Lake   141.0     Belmar   15.0    9/1/18 7:38
# 4     ...      Spring Lake   141.0  Manasquan   79.0   9/1/18 11:12
#
#     actual_time delay_minutes    status                     line        type
# 0  9/1/18 10:43      5.100000  departed  North Jersey Coast Line  NJ Transit
# 1   9/1/18 9:16      4.166667  departed  North Jersey Coast Line  NJ Transit
# 2  9/1/18 21:41      5.300000  departed  North Jersey Coast Line  NJ Transit
# 3   9/1/18 7:43      5.133333  departed  North Jersey Coast Line  NJ Transit
# 4  9/1/18 11:25     13.066667  departed  North Jersey Coast Line  NJ Transit
#
# [5 rows x 24 columns]

# %%
NJT_clean = pd.DataFrame({"Date" : NJT_df["date"],
                          "County" : NJT_df["COUNTY"],
                          "Municipality" : NJT_df["MUN_LABEL"],
                          "Latitude" : NJT_df["LATITUDE"], 
                          "Longitude" : NJT_df["LONGITUDE"],
                          "Station" : NJT_df["STATION"],
                          "Rail Line1" : NJT_df["line"],
                          "Rail Line2" : NJT_df["RAIL_LINE"],
                          "Number of Stops" : NJT_df["stop_sequence"],
                          "Origin" : NJT_df["from"], 
                          "Destination" : NJT_df["to"],
                          "Scheduled time of departure" : NJT_df["scheduled_time"], 
                          "Actual time of departure" : NJT_df["actual_time"], 
                          "Delay in Minutes" : NJT_df["delay_minutes"], 
                          "Status" : NJT_df["status"], 
                          "Owned by Amtrak?" : NJT_df["AMTRAK"], 
                          "Service Owner" : NJT_df["type"]})

# %%
NJT_clean["Date"].count()
NJT_clean.dropna(axis = 0, how = "any", inplace = True)
NJT_clean["Date"].count()
# Out:
# 202341

# %%
NJT_clean["Delay in Minutes"].describe()
NJT_clean["Number of Stops"].describe()
NJT_clean.head(20)
# Out:
#       Date    County         Municipality   Latitude  Longitude      Station  \
# 0   9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 1   9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 2   9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 3   9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 4   9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 5   9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 6   9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 7   9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 8   9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 9   9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 10  9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 11  9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 12  9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 13  9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 14  9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 15  9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 16  9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 17  9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 18  9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
# 19  9/1/18  MONMOUTH  Spring Lake Borough  40.150567  -74.03546  Spring Lake
#
#                  Rail Line1               Rail Line2  Number of Stops  \
# 0   North Jersey Coast Line  North Jersey Coast Line              5.0
# 1   North Jersey Coast Line  North Jersey Coast Line              8.0
# 2   North Jersey Coast Line  North Jersey Coast Line              5.0
# 3   North Jersey Coast Line  North Jersey Coast Line              5.0
# 4   North Jersey Coast Line  North Jersey Coast Line              8.0
# 5   North Jersey Coast Line  North Jersey Coast Line              8.0
# 6   North Jersey Coast Line  North Jersey Coast Line              8.0
# 7   North Jersey Coast Line  North Jersey Coast Line              5.0
# 8   North Jersey Coast Line  North Jersey Coast Line              5.0
# 9   North Jersey Coast Line  North Jersey Coast Line              8.0
# 10  North Jersey Coast Line  North Jersey Coast Line              8.0
# 11  North Jersey Coast Line  North Jersey Coast Line              8.0
# 12  North Jersey Coast Line  North Jersey Coast Line              8.0
# 13  North Jersey Coast Line  North Jersey Coast Line              5.0
# 14  North Jersey Coast Line  North Jersey Coast Line              5.0
# 15  North Jersey Coast Line  North Jersey Coast Line              8.0
# 16  North Jersey Coast Line  North Jersey Coast Line              5.0
# 17  North Jersey Coast Line  North Jersey Coast Line              8.0
# 18  North Jersey Coast Line  North Jersey Coast Line              5.0
# 19  North Jersey Coast Line  North Jersey Coast Line              8.0
#
#          Origin Destination Scheduled time of departure  \
# 0   Spring Lake      Belmar                9/1/18 10:38
# 1   Spring Lake   Manasquan                 9/1/18 9:12
# 2   Spring Lake      Belmar                9/1/18 21:36
# 3   Spring Lake      Belmar                 9/1/18 7:38
# 4   Spring Lake   Manasquan                9/1/18 11:12
# 5   Spring Lake   Manasquan                9/1/18 15:12
# 6   Spring Lake   Manasquan                9/1/18 22:12
# 7   Spring Lake      Belmar                9/1/18 17:36
# 8   Spring Lake      Belmar                9/1/18 18:36
# 9   Spring Lake   Manasquan                9/1/18 12:12
# 10  Spring Lake   Manasquan                 9/2/18 3:07
# 11  Spring Lake   Manasquan                9/1/18 19:12
# 12  Spring Lake   Manasquan                9/1/18 18:12
# 13  Spring Lake      Belmar                9/1/18 20:38
# 14  Spring Lake      Belmar                9/1/18 11:38
# 15  Spring Lake   Manasquan                 9/2/18 1:12
# 16  Spring Lake      Belmar                9/1/18 13:36
# 17  Spring Lake   Manasquan                9/1/18 14:12
# 18  Spring Lake      Belmar                9/1/18 15:36
# 19  Spring Lake   Manasquan                9/1/18 23:12
#
#    Actual time of departure  Delay in Minutes    Status Owned by Amtrak?  \
# 0              9/1/18 10:43          5.100000  departed                N
# 1               9/1/18 9:16          4.166667  departed                N
# 2              9/1/18 21:41          5.300000  departed                N
# 3               9/1/18 7:43          5.133333  departed                N
# 4              9/1/18 11:25         13.066667  departed                N
# 5              9/1/18 15:24         12.316667  departed                N
# 6              9/1/18 22:18          6.283333  departed                N
# 7              9/1/18 17:41          5.166667  departed                N
# 8              9/1/18 18:36          0.150000  departed                N
# 9              9/1/18 12:18          6.066667  departed                N
# 10              9/2/18 3:14          7.033333  departed                N
# 11             9/1/18 19:16          4.216667  departed                N
# 12             9/1/18 18:15          3.433333  departed                N
# 13             9/1/18 20:37          0.000000  departed                N
# 14             9/1/18 11:40          2.133333  departed                N
# 15              9/2/18 1:15          3.016667  departed                N
# 16             9/1/18 13:45          9.100000  departed                N
# 17             9/1/18 14:22         10.100000  departed                N
# 18             9/1/18 15:41          5.100000  departed                N
# 19             9/1/18 23:20          8.133333  departed                N
#
#    Service Owner
# 0     NJ Transit
# 1     NJ Transit
# 2     NJ Transit
# 3     NJ Transit
# 4     NJ Transit
# 5     NJ Transit
# 6     NJ Transit
# 7     NJ Transit
# 8     NJ Transit
# 9     NJ Transit
# 10    NJ Transit
# 11    NJ Transit
# 12    NJ Transit
# 13    NJ Transit
# 14    NJ Transit
# 15    NJ Transit
# 16    NJ Transit
# 17    NJ Transit
# 18    NJ Transit
# 19    NJ Transit

# %%
NJT_clean.to_csv("NJT_clean.csv", encoding='utf-8', index=False)
